# %%
import pandas as pd

# %%
df = pd.read_csv('/content/House Price India.csv')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df['number of bathrooms'].mean()         #calculating mean
# Out:
# 2.1295827633378934

# %%
df['number of bathrooms'].median()       #calculating median
# Out:
# 2.25

# %%
df['number of bathrooms'].std()           #calculating standard deviation
# Out:
# 0.769934496031654

# %%
df['number of bathrooms'].value_counts()      #calculating frequency table
# Out:
# 2.50    3678
# 1.00    2509
# 1.75    2062
# 2.25    1378
# 2.00    1323
# 1.50     968
# 2.75     831
# 3.00     510
# 3.50     504
# 3.25     424
# 3.75     101
# 4.00      81
# 4.50      72
# 4.25      56
# 0.75      47
# 4.75      17
# 5.00      15
# 5.25      12
# 5.50       8
# 1.25       7
# 0.50       3
# 6.00       3
# 8.00       2
# 5.75       2
# 6.25       2
# 6.75       2
# 6.50       1
# 7.50       1
# 7.75       1
# Name: number of bathrooms, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.hist(column='number of bathrooms' , grid=False , edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'number of bathrooms'}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.kdeplot(df['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='Density'>

# %% [markdown]
# ##BIVARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#creating scatterplot

plt.scatter(df.living_area_renov, df.lot_area_renov)
plt.title('Living area vs Lot area')
plt.xlabel('Living area renovation')
plt.ylabel('Lot area renovation')
# Out:
# Text(0, 0.5, 'Lot area renovation')

# %%
#create correlation matrix

df.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
# regression model

import statsmodels.api as sm

# %%
y = df['number of bathrooms']
x = df['number of floors']

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y, x).fit()

# %%
print(model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     number of bathrooms   R-squared:                       0.253
# Model:                             OLS   Adj. R-squared:                  0.253
# Method:                  Least Squares   F-statistic:                     4949.
# Date:                 Wed, 06 Sep 2023   Prob (F-statistic):               0.00
# Time:                         10:57:47   Log-Likelihood:                -14790.
# No. Observations:                14620   AIC:                         2.958e+04
# Df Residuals:                    14618   BIC:                         2.960e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.0528      0.016     64.721      0.000       1.021       1.085
# ...

# %% [markdown]
# #Multivariate analysis

# %%
df.loc[:,"number of bedrooms":"number of views"]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views
# 0                   2.0                   0                4
# ...

# %%
df.describe()    #descriptive analysis
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...
